# %%
import torch
import torch.nn as nn
from torch_geometric.loader import DataLoader
from schnetspec import SchNetspec
from pyg_schnet import SchNet
from create_dataset import XASDataset
# Out:
# INFO:rdkit:Enabling RDKit 2024.03.5 jupyter extensions

# %%
def train(train_loader, model, criterion, optimizer, epoch, device):

    model.train()

    loss_all = 0

    for batch in train_loader:
        batch = batch.to(device)

        optimizer.zero_grad()

        output = model(batch.z, batch.x, batch.batch)

        target = torch.Tensor(batch.spectrum).to(device)

        train_loss = criterion(output.double(), target.double())

        loss_all += train_loss.data * batch.num_graphs

        train_loss.backward()

        optimizer.step()

    return loss_all
    
def validate(val_loader, model, criterion, epoch, device):
    losses_all = 0

    model.eval()

    for batch in val_loader:
        batch = batch.to(device)

        output = model(batch.z, batch.x, batch.batch)

        target = torch.Tensor(batch.spectrum).to(device)

        val_loss = criterion(output.double(), target.double())

        losses_all += val_loss.data * batch.num_graphs

    return losses_all

# %%
data = XASDataset('./')
# Out:
# /home/samjhall/miniconda3/envs/pyg-schnet/lib/python3.11/site-packages/torch_geometric/data/dataset.py:238: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   if osp.exists(f) and torch.load(f) != _repr(self.pre_transform):
# /home/samjhall/miniconda3/envs/pyg-schnet/lib/python3.11/site-packages/torch_geometric/data/dataset.py:246: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   if osp.exists(f) and torch.load(f) != _repr(self.pre_filter):

# %%
train_dataset = data[0:10]#113249]
val_dataset = data[11:20]#113249:119541]

train_loader = DataLoader(train_dataset, batch_size=50, shuffle=False, num_workers=0)
val_loader = DataLoader(val_dataset, batch_size=50, shuffle=True, num_workers=0)

conv = SchNet(hidden_channels=300, num_filters=200, num_interactions=6,
                  num_gaussians=50, cutoff=10.0)

# %%
for batch in train_loader:
    print(batch)
    break
# Out:
# DataBatch(x=[182, 3], edge_index=[2, 182], edge_attr=[182, 4], spectrum=[3000], z=[182], idx=[10], smiles=[10], batch=[182], ptr=[11])

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = conv.to(device)

# %%
model
# Out:
# SchNet(hidden_channels=300, num_filters=200, num_interactions=6, num_gaussians=50, cutoff=10.0)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min',
                                                       factor=0.9, patience=5,
                                                       min_lr=0.000001)
criterion = nn.MSELoss()

# %%
loss_train = []

for epoch in range(300):
    lr = scheduler.optimizer.param_groups[0]['lr']

    train_loss = (train(train_loader, model, criterion, optimizer, epoch, device)/(len(train_dataset)))

    print(train_loss)

    val_loss = (validate(val_loader, model, criterion, epoch, device)/len(val_dataset))

    print(val_loss)

    scheduler.step(val_loss)
# Out:
# /home/samjhall/miniconda3/envs/pyg-schnet/lib/python3.11/site-packages/torch/nn/modules/loss.py:538: UserWarning: Using a target size (torch.Size([3000])) that is different to the input size (torch.Size([10, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# tensor(46.5009, dtype=torch.float64)
# tensor(12117.4524, dtype=torch.float64)
# /home/samjhall/miniconda3/envs/pyg-schnet/lib/python3.11/site-packages/torch/nn/modules/loss.py:538: UserWarning: Using a target size (torch.Size([2700])) that is different to the input size (torch.Size([9, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# tensor(19513.6994, dtype=torch.float64)
# tensor(966.0238, dtype=torch.float64)
# tensor(1383.2972, dtype=torch.float64)
# tensor(90.0306, dtype=torch.float64)
# tensor(128.6611, dtype=torch.float64)
# tensor(791.1295, dtype=torch.float64)
# tensor(1073.4461, dtype=torch.float64)
# tensor(828.5694, dtype=torch.float64)
# tensor(1076.2567, dtype=torch.float64)
# tensor(373.3004, dtype=torch.float64)
# tensor(441.6027, dtype=torch.float64)
# tensor(28.8363, dtype=torch.float64)
# tensor(21.8099, dtype=torch.float64)
# tensor(125.8554, dtype=torch.float64)
# tensor(259.8282, dtype=torch.float64)
# tensor(289.6558, dtype=torch.float64)
# tensor(515.6080, dtype=torch.float64)
# tensor(172.9860, dtype=torch.float64)
# tensor(296.0455, dtype=torch.float64)
# tensor(30.5391, dtype=torch.float64)
# tensor(51.6172, dtype=torch.float64)
# tensor(11.8333, dtype=torch.float64)
# tensor(9.7059, dtype=torch.float64)
# tensor(78.0135, dtype=torch.float64)
# tensor(101.0262, dtype=torch.float64)
# tensor(132.8564, dtype=torch.float64)
# tensor(176.8667, dtype=torch.float64)
# tensor(125.4296, dtype=torch.float64)
# tensor(162.2553, dtype=torch.float64)
# tensor(74.8964, dtype=torch.float64)
# tensor(89.1461, dtype=torch.float64)
# tensor(24.7408, dtype=torch.float64)
# tensor(22.5500, dtype=torch.float64)
# tensor(3.5568, dtype=torch.float64)
# tensor(2.0143, dtype=torch.float64)
# tensor(13.1895, dtype=torch.float64)
# tensor(26.6164, dtype=torch.float64)
# tensor(33.3249, dtype=torch.float64)
# tensor(63.0640, dtype=torch.float64)
# tensor(40.3320, dtype=torch.float64)
# tensor(74.5836, dtype=torch.float64)
# tensor(28.9338, dtype=torch.float64)
# tensor(54.1453, dtype=torch.float64)
# tensor(11.8937, dtype=torch.float64)
# tensor(22.8599, dtype=torch.float64)
# tensor(3.3885, dtype=torch.float64)
# tensor(3.5185, dtype=torch.float64)
# tensor(7.8924, dtype=torch.float64)
# tensor(3.8604, dtype=torch.float64)
# tensor(20.2341, dtype=torch.float64)
# tensor(17.1358, dtype=torch.float64)
# tensor(31.3506, dtype=torch.float64)
# tensor(30.7021, dtype=torch.float64)
# tensor(34.4924, dtype=torch.float64)
# tensor(34.9412, dtype=torch.float64)
# tensor(28.6411, dtype=torch.float64)
# tensor(28.1288, dtype=torch.float64)
# tensor(17.8725, dtype=torch.float64)
# tensor(15.5506, dtype=torch.float64)
# tensor(8.7471, dtype=torch.float64)
# tensor(5.5492, dtype=torch.float64)
# tensor(3.4894, dtype=torch.float64)
# tensor(1.0123, dtype=torch.float64)
# tensor(2.9197, dtype=torch.float64)
# tensor(2.6640, dtype=torch.float64)
# tensor(5.3966, dtype=torch.float64)
# tensor(7.9211, dtype=torch.float64)
# tensor(8.1718, dtype=torch.float64)
# tensor(12.8114, dtype=torch.float64)
# tensor(9.0944, dtype=torch.float64)
# tensor(14.3324, dtype=torch.float64)
# tensor(7.6821, dtype=torch.float64)
# tensor(11.9047, dtype=torch.float64)
# tensor(5.0405, dtype=torch.float64)
# tensor(7.2188, dtype=torch.float64)
# tensor(2.8931, dtype=torch.float64)
# tensor(2.8589, dtype=torch.float64)
# tensor(2.4697, dtype=torch.float64)
# tensor(0.7434, dtype=torch.float64)
# tensor(3.8967, dtype=torch.float64)
# tensor(1.2645, dtype=torch.float64)
# tensor(6.2939, dtype=torch.float64)
# tensor(3.4016, dtype=torch.float64)
# tensor(8.3740, dtype=torch.float64)
# tensor(5.5237, dtype=torch.float64)
# tensor(9.1453, dtype=torch.float64)
# tensor(6.3388, dtype=torch.float64)
# tensor(8.3507, dtype=torch.float64)
# tensor(5.4893, dtype=torch.float64)
# tensor(6.4721, dtype=torch.float64)
# tensor(3.5622, dtype=torch.float64)
# tensor(4.5538, dtype=torch.float64)
# tensor(1.7679, dtype=torch.float64)
# tensor(3.0392, dtype=torch.float64)
# tensor(0.6484, dtype=torch.float64)
# tensor(2.2571, dtype=torch.float64)
# tensor(0.5186, dtype=torch.float64)
# tensor(2.1459, dtype=torch.float64)
# tensor(1.1730, dtype=torch.float64)
# tensor(2.3757, dtype=torch.float64)
# tensor(2.0673, dtype=torch.float64)
# tensor(2.5764, dtype=torch.float64)
# tensor(2.6391, dtype=torch.float64)
# tensor(2.5404, dtype=torch.float64)
# tensor(2.5896, dtype=torch.float64)
# tensor(2.3010, dtype=torch.float64)
# tensor(1.9886, dtype=torch.float64)
# tensor(2.0648, dtype=torch.float64)
# tensor(1.1764, dtype=torch.float64)
# tensor(2.0581, dtype=torch.float64)
# tensor(0.5448, dtype=torch.float64)
# tensor(2.3834, dtype=torch.float64)
# tensor(0.3298, dtype=torch.float64)
# tensor(2.9625, dtype=torch.float64)
# tensor(0.5193, dtype=torch.float64)
# tensor(3.5815, dtype=torch.float64)
# tensor(0.9027, dtype=torch.float64)
# tensor(4.0030, dtype=torch.float64)
# tensor(1.2115, dtype=torch.float64)
# tensor(4.0776, dtype=torch.float64)
# tensor(1.2660, dtype=torch.float64)
# tensor(3.8018, dtype=torch.float64)
# tensor(1.0516, dtype=torch.float64)
# tensor(3.3466, dtype=torch.float64)
# tensor(0.7289, dtype=torch.float64)
# tensor(2.8329, dtype=torch.float64)
# tensor(0.4279, dtype=torch.float64)
# tensor(2.3915, dtype=torch.float64)
# tensor(0.2669, dtype=torch.float64)
# tensor(2.0913, dtype=torch.float64)
# tensor(0.2793, dtype=torch.float64)
# tensor(1.9313, dtype=torch.float64)
# tensor(0.4109, dtype=torch.float64)
# tensor(1.8655, dtype=torch.float64)
# tensor(0.5599, dtype=torch.float64)
# tensor(1.8422, dtype=torch.float64)
# tensor(0.6349, dtype=torch.float64)
# tensor(1.8345, dtype=torch.float64)
# tensor(0.5978, dtype=torch.float64)
# tensor(1.8491, dtype=torch.float64)
# tensor(0.4742, dtype=torch.float64)
# tensor(1.9113, dtype=torch.float64)
# tensor(0.3298, dtype=torch.float64)
# tensor(2.0398, dtype=torch.float64)
# tensor(0.2301, dtype=torch.float64)
# tensor(2.2266, dtype=torch.float64)
# tensor(0.2079, dtype=torch.float64)
# tensor(2.4336, dtype=torch.float64)
# tensor(0.2514, dtype=torch.float64)
# tensor(2.6064, dtype=torch.float64)
# tensor(0.3182, dtype=torch.float64)
# tensor(2.6876, dtype=torch.float64)
# tensor(0.3574, dtype=torch.float64)
# tensor(2.6762, dtype=torch.float64)
# tensor(0.3536, dtype=torch.float64)
# tensor(2.5805, dtype=torch.float64)
# tensor(0.3107, dtype=torch.float64)
# tensor(2.4292, dtype=torch.float64)
# tensor(0.2506, dtype=torch.float64)
# tensor(2.2590, dtype=torch.float64)
# tensor(0.2002, dtype=torch.float64)
# tensor(2.1020, dtype=torch.float64)
# tensor(0.1775, dtype=torch.float64)
# tensor(1.9891, dtype=torch.float64)
# tensor(0.1824, dtype=torch.float64)
# tensor(1.9087, dtype=torch.float64)
# tensor(0.2018, dtype=torch.float64)
# tensor(1.8590, dtype=torch.float64)
# tensor(0.2215, dtype=torch.float64)
# tensor(1.8354, dtype=torch.float64)
# tensor(0.2301, dtype=torch.float64)
# tensor(1.8344, dtype=torch.float64)
# tensor(0.2232, dtype=torch.float64)
# tensor(1.8540, dtype=torch.float64)
# tensor(0.2043, dtype=torch.float64)
# tensor(1.8888, dtype=torch.float64)
# tensor(0.1838, dtype=torch.float64)
# tensor(1.9379, dtype=torch.float64)
# tensor(0.1670, dtype=torch.float64)
# tensor(1.9962, dtype=torch.float64)
# tensor(0.1587, dtype=torch.float64)
# tensor(2.0559, dtype=torch.float64)
# tensor(0.1592, dtype=torch.float64)
# tensor(2.1078, dtype=torch.float64)
# tensor(0.1653, dtype=torch.float64)
# tensor(2.1435, dtype=torch.float64)
# tensor(0.1722, dtype=torch.float64)
# tensor(2.1558, dtype=torch.float64)
# tensor(0.1752, dtype=torch.float64)
# tensor(2.1472, dtype=torch.float64)
# tensor(0.1733, dtype=torch.float64)
# tensor(2.1202, dtype=torch.float64)
# tensor(0.1672, dtype=torch.float64)
# tensor(2.0797, dtype=torch.float64)
# tensor(0.1592, dtype=torch.float64)
# tensor(2.0319, dtype=torch.float64)
# tensor(0.1518, dtype=torch.float64)
# tensor(1.9830, dtype=torch.float64)
# tensor(0.1471, dtype=torch.float64)
# tensor(1.9425, dtype=torch.float64)
# tensor(0.1457, dtype=torch.float64)
# tensor(1.9083, dtype=torch.float64)
# tensor(0.1463, dtype=torch.float64)
# tensor(1.8820, dtype=torch.float64)
# tensor(0.1480, dtype=torch.float64)
# tensor(1.8644, dtype=torch.float64)
# tensor(0.1493, dtype=torch.float64)
# tensor(1.8554, dtype=torch.float64)
# tensor(0.1494, dtype=torch.float64)
# tensor(1.8543, dtype=torch.float64)
# tensor(0.1479, dtype=torch.float64)
# tensor(1.8597, dtype=torch.float64)
# tensor(0.1456, dtype=torch.float64)
# tensor(1.8704, dtype=torch.float64)
# tensor(0.1428, dtype=torch.float64)
# tensor(1.8848, dtype=torch.float64)
# tensor(0.1401, dtype=torch.float64)
# tensor(1.9014, dtype=torch.float64)
# tensor(0.1383, dtype=torch.float64)
# tensor(1.9181, dtype=torch.float64)
# tensor(0.1373, dtype=torch.float64)
# tensor(1.9332, dtype=torch.float64)
# tensor(0.1370, dtype=torch.float64)
# tensor(1.9437, dtype=torch.float64)
# tensor(0.1372, dtype=torch.float64)
# tensor(1.9501, dtype=torch.float64)
# tensor(0.1373, dtype=torch.float64)
# tensor(1.9519, dtype=torch.float64)
# tensor(0.1371, dtype=torch.float64)
# tensor(1.9492, dtype=torch.float64)
# tensor(0.1365, dtype=torch.float64)
# tensor(1.9422, dtype=torch.float64)
# tensor(0.1356, dtype=torch.float64)
# tensor(1.9319, dtype=torch.float64)
# tensor(0.1344, dtype=torch.float64)
# tensor(1.9206, dtype=torch.float64)
# tensor(0.1333, dtype=torch.float64)
# tensor(1.9081, dtype=torch.float64)
# tensor(0.1324, dtype=torch.float64)
# tensor(1.8954, dtype=torch.float64)
# tensor(0.1316, dtype=torch.float64)
# tensor(1.8834, dtype=torch.float64)
# tensor(0.1311, dtype=torch.float64)
# tensor(1.8727, dtype=torch.float64)
# tensor(0.1308, dtype=torch.float64)
# tensor(1.8638, dtype=torch.float64)
# tensor(0.1305, dtype=torch.float64)
# tensor(1.8577, dtype=torch.float64)
# tensor(0.1303, dtype=torch.float64)
# tensor(1.8535, dtype=torch.float64)
# tensor(0.1300, dtype=torch.float64)
# tensor(1.8513, dtype=torch.float64)
# tensor(0.1297, dtype=torch.float64)
# tensor(1.8509, dtype=torch.float64)
# tensor(0.1292, dtype=torch.float64)
# tensor(1.8520, dtype=torch.float64)
# tensor(0.1287, dtype=torch.float64)
# tensor(1.8542, dtype=torch.float64)
# tensor(0.1281, dtype=torch.float64)
# tensor(1.8570, dtype=torch.float64)
# tensor(0.1276, dtype=torch.float64)
# tensor(1.8601, dtype=torch.float64)
# tensor(0.1272, dtype=torch.float64)
# tensor(1.8632, dtype=torch.float64)
# tensor(0.1268, dtype=torch.float64)
# tensor(1.8661, dtype=torch.float64)
# tensor(0.1265, dtype=torch.float64)
# tensor(1.8684, dtype=torch.float64)
# tensor(0.1262, dtype=torch.float64)
# tensor(1.8700, dtype=torch.float64)
# tensor(0.1259, dtype=torch.float64)
# tensor(1.8706, dtype=torch.float64)
# tensor(0.1257, dtype=torch.float64)
# tensor(1.8704, dtype=torch.float64)
# tensor(0.1255, dtype=torch.float64)
# tensor(1.8692, dtype=torch.float64)
# tensor(0.1252, dtype=torch.float64)
# tensor(1.8673, dtype=torch.float64)
# tensor(0.1249, dtype=torch.float64)
# tensor(1.8648, dtype=torch.float64)
# tensor(0.1246, dtype=torch.float64)
# tensor(1.8617, dtype=torch.float64)
# tensor(0.1243, dtype=torch.float64)
# tensor(1.8585, dtype=torch.float64)
# tensor(0.1240, dtype=torch.float64)
# tensor(1.8552, dtype=torch.float64)
# tensor(0.1237, dtype=torch.float64)
# tensor(1.8518, dtype=torch.float64)
# tensor(0.1235, dtype=torch.float64)
# tensor(1.8485, dtype=torch.float64)
# tensor(0.1232, dtype=torch.float64)
# tensor(1.8454, dtype=torch.float64)
# tensor(0.1230, dtype=torch.float64)
# tensor(1.8426, dtype=torch.float64)
# tensor(0.1228, dtype=torch.float64)
# tensor(1.8403, dtype=torch.float64)
# tensor(0.1226, dtype=torch.float64)
# tensor(1.8384, dtype=torch.float64)
# tensor(0.1224, dtype=torch.float64)
# tensor(1.8368, dtype=torch.float64)
# tensor(0.1222, dtype=torch.float64)
# tensor(1.8356, dtype=torch.float64)
# tensor(0.1220, dtype=torch.float64)
# tensor(1.8347, dtype=torch.float64)
# tensor(0.1218, dtype=torch.float64)
# tensor(1.8341, dtype=torch.float64)
# tensor(0.1216, dtype=torch.float64)
# tensor(1.8337, dtype=torch.float64)
# tensor(0.1214, dtype=torch.float64)
# tensor(1.8336, dtype=torch.float64)
# tensor(0.1212, dtype=torch.float64)
# tensor(1.8335, dtype=torch.float64)
# tensor(0.1210, dtype=torch.float64)
# tensor(1.8335, dtype=torch.float64)
# tensor(0.1208, dtype=torch.float64)
# tensor(1.8335, dtype=torch.float64)
# tensor(0.1206, dtype=torch.float64)
# tensor(1.8334, dtype=torch.float64)
# tensor(0.1204, dtype=torch.float64)
# tensor(1.8333, dtype=torch.float64)
# tensor(0.1202, dtype=torch.float64)
# tensor(1.8330, dtype=torch.float64)
# tensor(0.1200, dtype=torch.float64)
# tensor(1.8326, dtype=torch.float64)
# tensor(0.1198, dtype=torch.float64)
# tensor(1.8320, dtype=torch.float64)
# tensor(0.1196, dtype=torch.float64)
# tensor(1.8313, dtype=torch.float64)
# tensor(0.1194, dtype=torch.float64)
# tensor(1.8304, dtype=torch.float64)
# tensor(0.1193, dtype=torch.float64)
# tensor(1.8293, dtype=torch.float64)
# tensor(0.1191, dtype=torch.float64)
# tensor(1.8281, dtype=torch.float64)
# tensor(0.1189, dtype=torch.float64)
# tensor(1.8268, dtype=torch.float64)
# tensor(0.1187, dtype=torch.float64)
# tensor(1.8254, dtype=torch.float64)
# tensor(0.1185, dtype=torch.float64)
# tensor(1.8239, dtype=torch.float64)
# tensor(0.1184, dtype=torch.float64)
# tensor(1.8225, dtype=torch.float64)
# tensor(0.1182, dtype=torch.float64)
# tensor(1.8211, dtype=torch.float64)
# tensor(0.1180, dtype=torch.float64)
# tensor(1.8197, dtype=torch.float64)
# tensor(0.1178, dtype=torch.float64)
# tensor(1.8184, dtype=torch.float64)
# tensor(0.1177, dtype=torch.float64)
# tensor(1.8171, dtype=torch.float64)
# tensor(0.1175, dtype=torch.float64)
# tensor(1.8160, dtype=torch.float64)
# tensor(0.1173, dtype=torch.float64)
# tensor(1.8149, dtype=torch.float64)
# tensor(0.1172, dtype=torch.float64)
# tensor(1.8140, dtype=torch.float64)
# tensor(0.1170, dtype=torch.float64)
# tensor(1.8131, dtype=torch.float64)
# tensor(0.1168, dtype=torch.float64)
# tensor(1.8123, dtype=torch.float64)
# tensor(0.1167, dtype=torch.float64)
# tensor(1.8116, dtype=torch.float64)
# tensor(0.1165, dtype=torch.float64)
# tensor(1.8109, dtype=torch.float64)
# tensor(0.1163, dtype=torch.float64)
# tensor(1.8102, dtype=torch.float64)
# tensor(0.1162, dtype=torch.float64)
# tensor(1.8096, dtype=torch.float64)
# tensor(0.1160, dtype=torch.float64)
# tensor(1.8090, dtype=torch.float64)
# tensor(0.1158, dtype=torch.float64)
# tensor(1.8083, dtype=torch.float64)
# tensor(0.1157, dtype=torch.float64)
# tensor(1.8077, dtype=torch.float64)
# tensor(0.1155, dtype=torch.float64)
# tensor(1.8070, dtype=torch.float64)
# tensor(0.1154, dtype=torch.float64)
# tensor(1.8062, dtype=torch.float64)
# tensor(0.1152, dtype=torch.float64)
# tensor(1.8054, dtype=torch.float64)
# tensor(0.1151, dtype=torch.float64)
# tensor(1.8046, dtype=torch.float64)
# tensor(0.1149, dtype=torch.float64)
# tensor(1.8038, dtype=torch.float64)
# tensor(0.1148, dtype=torch.float64)
# tensor(1.8029, dtype=torch.float64)
# tensor(0.1146, dtype=torch.float64)
# tensor(1.8019, dtype=torch.float64)
# tensor(0.1145, dtype=torch.float64)
# tensor(1.8010, dtype=torch.float64)
# tensor(0.1143, dtype=torch.float64)
# tensor(1.8000, dtype=torch.float64)
# tensor(0.1142, dtype=torch.float64)
# tensor(1.7991, dtype=torch.float64)
# tensor(0.1140, dtype=torch.float64)
# tensor(1.7981, dtype=torch.float64)
# tensor(0.1139, dtype=torch.float64)
# tensor(1.7972, dtype=torch.float64)
# tensor(0.1137, dtype=torch.float64)
# tensor(1.7963, dtype=torch.float64)
# tensor(0.1136, dtype=torch.float64)
# tensor(1.7954, dtype=torch.float64)
# tensor(0.1135, dtype=torch.float64)
# tensor(1.7945, dtype=torch.float64)
# tensor(0.1133, dtype=torch.float64)
# tensor(1.7937, dtype=torch.float64)
# tensor(0.1132, dtype=torch.float64)
# tensor(1.7929, dtype=torch.float64)
# tensor(0.1130, dtype=torch.float64)
# tensor(1.7921, dtype=torch.float64)
# tensor(0.1129, dtype=torch.float64)
# tensor(1.7913, dtype=torch.float64)
# tensor(0.1128, dtype=torch.float64)
# tensor(1.7906, dtype=torch.float64)
# tensor(0.1126, dtype=torch.float64)
# tensor(1.7899, dtype=torch.float64)
# tensor(0.1125, dtype=torch.float64)
# tensor(1.7892, dtype=torch.float64)
# tensor(0.1124, dtype=torch.float64)
# tensor(1.7885, dtype=torch.float64)
# tensor(0.1122, dtype=torch.float64)
# tensor(1.7878, dtype=torch.float64)
# tensor(0.1121, dtype=torch.float64)
# tensor(1.7871, dtype=torch.float64)
# tensor(0.1120, dtype=torch.float64)
# tensor(1.7864, dtype=torch.float64)
# tensor(0.1118, dtype=torch.float64)
# tensor(1.7857, dtype=torch.float64)
# tensor(0.1117, dtype=torch.float64)
# tensor(1.7850, dtype=torch.float64)
# tensor(0.1116, dtype=torch.float64)
# tensor(1.7842, dtype=torch.float64)
# tensor(0.1115, dtype=torch.float64)
# tensor(1.7835, dtype=torch.float64)
# tensor(0.1113, dtype=torch.float64)
# tensor(1.7827, dtype=torch.float64)
# tensor(0.1112, dtype=torch.float64)
# tensor(1.7820, dtype=torch.float64)
# tensor(0.1111, dtype=torch.float64)
# tensor(1.7813, dtype=torch.float64)
# tensor(0.1110, dtype=torch.float64)
# tensor(1.7805, dtype=torch.float64)
# tensor(0.1108, dtype=torch.float64)
# tensor(1.7798, dtype=torch.float64)
# tensor(0.1107, dtype=torch.float64)
# tensor(1.7790, dtype=torch.float64)
# tensor(0.1106, dtype=torch.float64)
# tensor(1.7783, dtype=torch.float64)
# tensor(0.1105, dtype=torch.float64)
# tensor(1.7775, dtype=torch.float64)
# tensor(0.1104, dtype=torch.float64)
# tensor(1.7768, dtype=torch.float64)
# tensor(0.1103, dtype=torch.float64)
# tensor(1.7761, dtype=torch.float64)
# tensor(0.1101, dtype=torch.float64)
# tensor(1.7754, dtype=torch.float64)
# tensor(0.1100, dtype=torch.float64)
# tensor(1.7747, dtype=torch.float64)
# tensor(0.1099, dtype=torch.float64)
# tensor(1.7741, dtype=torch.float64)
# tensor(0.1098, dtype=torch.float64)
# tensor(1.7734, dtype=torch.float64)
# tensor(0.1097, dtype=torch.float64)
# tensor(1.7727, dtype=torch.float64)
# tensor(0.1096, dtype=torch.float64)
# tensor(1.7721, dtype=torch.float64)
# tensor(0.1095, dtype=torch.float64)
# tensor(1.7715, dtype=torch.float64)
# tensor(0.1094, dtype=torch.float64)
# tensor(1.7708, dtype=torch.float64)
# tensor(0.1093, dtype=torch.float64)
# tensor(1.7702, dtype=torch.float64)
# tensor(0.1091, dtype=torch.float64)
# tensor(1.7696, dtype=torch.float64)
# tensor(0.1090, dtype=torch.float64)
# tensor(1.7689, dtype=torch.float64)
# tensor(0.1089, dtype=torch.float64)
# tensor(1.7683, dtype=torch.float64)
# tensor(0.1088, dtype=torch.float64)
# tensor(1.7677, dtype=torch.float64)
# tensor(0.1087, dtype=torch.float64)
# tensor(1.7670, dtype=torch.float64)
# tensor(0.1086, dtype=torch.float64)
# tensor(1.7664, dtype=torch.float64)
# tensor(0.1085, dtype=torch.float64)
# tensor(1.7658, dtype=torch.float64)
# tensor(0.1084, dtype=torch.float64)
# tensor(1.7652, dtype=torch.float64)
# tensor(0.1083, dtype=torch.float64)
# tensor(1.7646, dtype=torch.float64)
# tensor(0.1082, dtype=torch.float64)
# tensor(1.7639, dtype=torch.float64)
# tensor(0.1081, dtype=torch.float64)
# tensor(1.7633, dtype=torch.float64)
# tensor(0.1080, dtype=torch.float64)
# tensor(1.7627, dtype=torch.float64)
# tensor(0.1079, dtype=torch.float64)
# tensor(1.7621, dtype=torch.float64)
# tensor(0.1078, dtype=torch.float64)
# tensor(1.7615, dtype=torch.float64)
# tensor(0.1077, dtype=torch.float64)
# tensor(1.7609, dtype=torch.float64)
# tensor(0.1076, dtype=torch.float64)
# tensor(1.7603, dtype=torch.float64)
# tensor(0.1076, dtype=torch.float64)
# tensor(1.7597, dtype=torch.float64)
# tensor(0.1075, dtype=torch.float64)
# tensor(1.7592, dtype=torch.float64)
# tensor(0.1074, dtype=torch.float64)
# tensor(1.7586, dtype=torch.float64)
# tensor(0.1073, dtype=torch.float64)
# tensor(1.7580, dtype=torch.float64)
# tensor(0.1072, dtype=torch.float64)
# tensor(1.7575, dtype=torch.float64)
# tensor(0.1071, dtype=torch.float64)
# tensor(1.7569, dtype=torch.float64)
# tensor(0.1070, dtype=torch.float64)
# tensor(1.7564, dtype=torch.float64)
# tensor(0.1069, dtype=torch.float64)
# tensor(1.7558, dtype=torch.float64)
# tensor(0.1068, dtype=torch.float64)
# tensor(1.7553, dtype=torch.float64)
# tensor(0.1068, dtype=torch.float64)
# tensor(1.7547, dtype=torch.float64)
# tensor(0.1067, dtype=torch.float64)
# tensor(1.7542, dtype=torch.float64)
# tensor(0.1066, dtype=torch.float64)
# tensor(1.7537, dtype=torch.float64)
# tensor(0.1065, dtype=torch.float64)
# tensor(1.7531, dtype=torch.float64)
# tensor(0.1064, dtype=torch.float64)
# tensor(1.7526, dtype=torch.float64)
# tensor(0.1063, dtype=torch.float64)
# tensor(1.7521, dtype=torch.float64)
# tensor(0.1063, dtype=torch.float64)
# tensor(1.7516, dtype=torch.float64)
# tensor(0.1062, dtype=torch.float64)
# tensor(1.7511, dtype=torch.float64)
# tensor(0.1061, dtype=torch.float64)
# tensor(1.7505, dtype=torch.float64)
# tensor(0.1060, dtype=torch.float64)
# tensor(1.7500, dtype=torch.float64)
# tensor(0.1059, dtype=torch.float64)
# tensor(1.7495, dtype=torch.float64)
# tensor(0.1059, dtype=torch.float64)
# tensor(1.7490, dtype=torch.float64)
# tensor(0.1058, dtype=torch.float64)
# tensor(1.7485, dtype=torch.float64)
# tensor(0.1057, dtype=torch.float64)
# tensor(1.7480, dtype=torch.float64)
# tensor(0.1056, dtype=torch.float64)
# tensor(1.7475, dtype=torch.float64)
# tensor(0.1056, dtype=torch.float64)
# tensor(1.7470, dtype=torch.float64)
# tensor(0.1055, dtype=torch.float64)
# tensor(1.7466, dtype=torch.float64)
# tensor(0.1054, dtype=torch.float64)
# tensor(1.7461, dtype=torch.float64)
# tensor(0.1053, dtype=torch.float64)
# tensor(1.7456, dtype=torch.float64)
# tensor(0.1053, dtype=torch.float64)
# tensor(1.7451, dtype=torch.float64)
# tensor(0.1052, dtype=torch.float64)
# tensor(1.7447, dtype=torch.float64)
# tensor(0.1051, dtype=torch.float64)
# tensor(1.7442, dtype=torch.float64)
# tensor(0.1050, dtype=torch.float64)
# tensor(1.7437, dtype=torch.float64)
# tensor(0.1050, dtype=torch.float64)
# tensor(1.7433, dtype=torch.float64)
# tensor(0.1049, dtype=torch.float64)
# tensor(1.7428, dtype=torch.float64)
# tensor(0.1048, dtype=torch.float64)
# tensor(1.7424, dtype=torch.float64)
# tensor(0.1048, dtype=torch.float64)
# tensor(1.7419, dtype=torch.float64)
# tensor(0.1047, dtype=torch.float64)
# tensor(1.7415, dtype=torch.float64)
# tensor(0.1046, dtype=torch.float64)
# tensor(1.7410, dtype=torch.float64)
# tensor(0.1046, dtype=torch.float64)
# tensor(1.7406, dtype=torch.float64)
# tensor(0.1045, dtype=torch.float64)
# tensor(1.7402, dtype=torch.float64)
# tensor(0.1044, dtype=torch.float64)
# tensor(1.7397, dtype=torch.float64)
# tensor(0.1044, dtype=torch.float64)
# tensor(1.7393, dtype=torch.float64)
# tensor(0.1043, dtype=torch.float64)
# tensor(1.7389, dtype=torch.float64)
# tensor(0.1042, dtype=torch.float64)
# tensor(1.7385, dtype=torch.float64)
# tensor(0.1042, dtype=torch.float64)
# tensor(1.7380, dtype=torch.float64)
# tensor(0.1041, dtype=torch.float64)
# tensor(1.7376, dtype=torch.float64)
# tensor(0.1041, dtype=torch.float64)
# tensor(1.7372, dtype=torch.float64)
